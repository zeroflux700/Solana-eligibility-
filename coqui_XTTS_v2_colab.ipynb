# %% [markdown]
# <a href="https://colab.research.google.com/github/zeroflux700/Solana-eligibility-/blob/main/coqui_XTTS_v2_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/xtts2-hf
# %cd /content/xtts2-hf
# !pip install -q gradio==3.50.2 TTS==0.21.1 langid unidic-lite unidic deepspeed
# !pip install -q numpy<2.0.0 -U
# !wget https://huggingface.co/spaces/coqui/xtts/resolve/main/examples/female.wav -O /content/xtts2-hf/examples/female.wav
# !wget https://huggingface.co/spaces/coqui/xtts/resolve/main/examples/male.wav -O /content/xtts2-hf/examples/male.wav
# !wget https://huggingface.co/spaces/coqui/xtts/resolve/main/ffmpeg.zip -O /content/xtts2-hf/ffmpeg.zip
# !python app.py
# Out:
# /content
# Cloning into 'xtts2-hf'...
# remote: Enumerating objects: 518, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 518 (delta 2), reused 3 (delta 1), pack-reused 512 (from 1)
# Receiving objects: 100% (518/518), 716.12 KiB | 17.47 MiB/s, done.
# Resolving deltas: 100% (311/311), done.
# ...
# Error downloading object: examples/female.wav (89a4fa9): Smudge error: Error downloading examples/female.wav (89a4fa9a16b6463f852cf9424f72c3d3c87aa83010e89db534c53fcd1ae12c02): [89a4fa9a16b6463f852cf9424f72c3d3c87aa83010e89db534c53fcd1ae12c02] Object does not exist on the server: [404] Object does not exist on the server
#
# Errors logged to /content/xtts2-hf/.git/lfs/logs/20260420T153039.399016419.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: examples/female.wav: smudge filter lfs failed
# ...
# You can inspect what was checked out with 'git status'
# ...

# %%
# !pip install -q langid unidic-lite unidic pypinyin
# !python -m unidic download
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 59.7 MB/s eta 0:00:00
# ...
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:18<00:00, 29.1MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir

# %%
# !pip install -q TTS==0.22.0
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.0.10.2 Requires-Python >=3.6.0, <3.9; 0.0.10.3 Requires-Python >=3.6.0, <3.9; 0.0.11 Requires-Python >=3.6.0, <3.9; 0.0.12 Requires-Python >=3.6.0, <3.9; 0.0.13.1 Requires-Python >=3.6.0, <3.9; 0.0.13.2 Requires-Python >=3.6.0, <3.9; 0.0.14.1 Requires-Python >=3.6.0, <3.9; 0.0.15 Requires-Python >=3.6.0, <3.9; 0.0.15.1 Requires-Python >=3.6.0, <3.9; 0.0.9 Requires-Python >=3.6.0, <3.9; 0.0.9.1 Requires-Python >=3.6.0, <3.9; 0.0.9.2 Requires-Python >=3.6.0, <3.9; 0.0.9a10 Requires-Python >=3.6.0, <3.9; 0.0.9a9 Requires-Python >=3.6.0, <3.9; 0.1.0 Requires-Python >=3.6.0, <3.10; 0.1.1 Requires-Python >=3.6.0, <3.10; 0.1.2 Requires-Python >=3.6.0, <3.10; 0.1.3 Requires-Python >=3.6.0, <3.10; 0.10.0 Requires-Python >=3.7.0, <3.11; 0.10.1 Requires-Python >=3.7.0, <3.11; 0.10.2 Requires-Python >=3.7.0, <3.11; 0.11.0 Requires-Python >=3.7.0, <3.11; 0.11.1 Requires-Python >=3.7.0, <3.11; 0.12.0 Requires-Python >
# ...

# %%
# !pip install -q coqui-tts
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.8/862.8 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.3/997.3 kB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.4/648.4 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -q langid unidic-lite unidic pypinyin
# !python -m unidic download
# Out:
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:14<00:00, 36.3MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir

# %%
# %cd /content/xtts2-hf
# !python app.py
# Out:
# /content/xtts2-hf
# /content/xtts2-hf/app.py:238: SyntaxWarning: invalid escape sequence '\w'
#   prompt= re.sub("([^\x00-\x7F]|\w)(\.|\。|\?)",r"\1 \2\2",prompt)
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:17<00:00, 29.3MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# Traceback (most recent call last):
#   File "/content/xtts2-hf/app.py", line 34, in <module>
#     from TTS.utils.generic_utils import get_user_data_dir
# ImportError: cannot import name 'get_user_data_dir' from 'TTS.utils.generic_utils' (/usr/local/lib/python3.12/dist-packages/TTS/utils/generic_utils.py)

# %%
# !sed -i 's/from TTS.utils.generic_utils import get_user_data_dir/from TTS.utils.manage import get_user_data_dir/g' /content/xtts2-hf/app.py

# %%
# %cd /content/xtts2-hf
# !python app.py
# Out:
# /content/xtts2-hf
# /content/xtts2-hf/app.py:238: SyntaxWarning: invalid escape sequence '\w'
#   prompt= re.sub("([^\x00-\x7F]|\w)(\.|\。|\?)",r"\1 \2\2",prompt)
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:25<00:00, 21.0MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# Export newer ffmpeg binary for denoise filter
# Make ffmpeg binary executable
# ...
# XTTS downloaded
# Traceback (most recent call last):
#   File "/content/xtts2-hf/app.py", line 58, in <module>
#     model.load_checkpoint(
#   File "/usr/local/lib/python3.12/dist-packages/TTS/tts/models/xtts.py", line 779, in load_checkpoint
#     self.gpt.init_gpt_for_inference(kv_cache=self.args.kv_cache, use_deepspeed=use_deepspeed)
# ...

# %%
# %cd /content/xtts2-hf
# !python app.py

# %%
# !pip install -q deepspeed
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 16.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/xtts2-hf
# !python app.py
# Out:
# /content/xtts2-hf
# /content/xtts2-hf/app.py:238: SyntaxWarning: invalid escape sequence '\w'
#   prompt= re.sub("([^\x00-\x7F]|\w)(\.|\。|\?)",r"\1 \2\2",prompt)
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:18<00:00, 28.2MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# Export newer ffmpeg binary for denoise filter
# Make ffmpeg binary executable
# ...
# XTTS downloaded
# [2026-04-20 15:44:45,165] [WARNING] [config_utils.py:70:_process_deprecated_field] Config parameter replace_method is deprecated. This parameter is no longer needed, please remove from your call to DeepSpeed-inference
# [2026-04-20 15:44:45,166] [WARNING] [config_utils.py:70:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# ...

# %%
# !sed -i "s/info='Click on the windows/.../g" /content/xtts2-hf/app.py
# !sed -i "s/info='Upload a reference audio file',//g" /content/xtts2-hf/app.py

# %%
# %cd /content/xtts2-hf
# !python app.py
# Out:
# /content/xtts2-hf
# /content/xtts2-hf/app.py:238: SyntaxWarning: invalid escape sequence '\w'
#   prompt= re.sub("([^\x00-\x7F]|\w)(\.|\。|\?)",r"\1 \2\2",prompt)
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:17<00:00, 29.9MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# Export newer ffmpeg binary for denoise filter
# Make ffmpeg binary executable
# ...
# XTTS downloaded
# [2026-04-20 15:50:13,030] [WARNING] [config_utils.py:70:_process_deprecated_field] Config parameter replace_method is deprecated. This parameter is no longer needed, please remove from your call to DeepSpeed-inference
# [2026-04-20 15:50:13,030] [WARNING] [config_utils.py:70:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# ...

# %%
# !sed -i "s/info=[^,)]*//g" /content/xtts2-hf/app.py

# %%
# !sed -i "s/,,/,/g" /content/xtts2-hf/app.py
# !sed -i "s/(,/(/g" /content/xtts2-hf/app.py

# %%
# %cd /content/xtts2-hf
# !python app.py
# Out:
# /content/xtts2-hf
# /content/xtts2-hf/app.py:238: SyntaxWarning: invalid escape sequence '\w'
#   prompt= re.sub("([^\x00-\x7F]|\w)(\.|\。|\?)",r"\1 \2\2",prompt)
#   File "/content/xtts2-hf/app.py", line 616
#     ,
#     ^
# SyntaxError: invalid syntax

# %%
# %%writefile /content/xtts2-hf/app.py
import os
import gradio as gr
from TTS.api import TTS
import torch

# Set GPU
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load Model
print("Loading XTTS-v2...")
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

def clone_voice(text, audio_file):
    output_path = "output.wav"
        tts.tts_to_file(
                text=text,
                        speaker_wav=audio_file,
                                language="en",
                                        file_path=output_path
                                            )
                                                return output_path

                                                # Modern Gradio Interface (No 'info' or 'max_choices' bugs)
                                                with gr.Blocks() as demo:
                                                    gr.Markdown("# 🐶 Puppy Strategy: Instant Voice Clone")
                                                        with gr.Row():
                                                                with gr.Column():
                                                                            input_text = gr.Textbox(label="What should the voice say?", lines=3)
                                                                                        input_audio = gr.Audio(label="Upload Seed Voice (wav/mp3)", type="filepath")
                                                                                                    btn = gr.Button("Generate Voice Clone")
                                                                                                            with gr.Column():
                                                                                                                        output_audio = gr.Audio(label="Cloned Result")

                                                                                                                                btn.click(clone_voice, inputs=[input_text, input_audio], outputs=output_audio)

                                                                                                                                demo.launch(share=True)
# Out:
# Overwriting /content/xtts2-hf/app.py

# %%
# %%writefile /content/xtts2-hf/app.py
import os
import gradio as gr
from TTS.api import TTS
import torch

# Set GPU
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load Model
print("Loading XTTS-v2...")
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

def clone_voice(text, audio_file):
    output_path = "output.wav"
        tts.tts_to_file(
                text=text,
                        speaker_wav=audio_file,
                                language="en",
                                        file_path=output_path
                                            )
                                                return output_path

                                                # Modern Gradio Interface
                                                with gr.Blocks() as demo:
                                                    gr.Markdown("# 🐶 Puppy Strategy: Instant Voice Clone")
                                                        with gr.Row():
                                                                with gr.Column():
                                                                            input_text = gr.Textbox(label="What should the voice say?", lines=3)
                                                                                        input_audio = gr.Audio(label="Upload Seed Voice", type="filepath")
                                                                                                    btn = gr.Button("Generate Voice Clone")
                                                                                                            with gr.Column():
                                                                                                                        output_audio = gr.Audio(label="Cloned Result")

                                                                                                                                btn.click(clone_voice, inputs=[input_text, input_audio], outputs=output_audio)

                                                                                                                                if __name__ == "__main__":
                                                                                                                                    demo.launch(share=True)
# Out:
# Overwriting /content/xtts2-hf/app.py

# %%
# !python /content/xtts2-hf/app.py
# Out:
#   File "/content/xtts2-hf/app.py", line 15
#     tts.tts_to_file(
# IndentationError: unexpected indent

# %%
import os

content = """import os
import gradio as gr
from TTS.api import TTS
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

print("Loading XTTS-v2... This takes about 60 seconds.")
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

def clone_voice(text, audio_file):
    output_path = "output.wav"
        tts.tts_to_file(
                text=text,
                        speaker_wav=audio_file,
                                language="en",
                                        file_path=output_path
                                            )
                                                return output_path

                                                with gr.Blocks() as demo:
                                                    gr.Markdown("# 🐶 Puppy Strategy: Instant Voice Clone")
                                                        with gr.Row():
                                                                with gr.Column():
                                                                            input_text = gr.Textbox(label="What should the voice say?", lines=3)
                                                                                        input_audio = gr.Audio(label="Upload Seed Voice", type="filepath")
                                                                                                    btn = gr.Button("Generate Voice Clone")
                                                                                                            with gr.Column():
                                                                                                                        output_audio = gr.Audio(label="Cloned Result")

                                                                                                                                btn.click(clone_voice, inputs=[input_text, input_audio], outputs=output_audio)

                                                                                                                                if __name__ == "__main__":
                                                                                                                                    demo.launch(share=True)
                                                                                                                                    """

                                                                                                                                    with open("/content/xtts2-hf/app.py", "w") as f:
                                                                                                                                        f.write(content)

                                                                                                                                        print("✅ File written with perfect indentation!")
# Out:
#   File "/tmp/ipykernel_2459/1492761336.py", line 39
#     with open("/content/xtts2-hf/app.py", "w") as f:
#     ^
# IndentationError: unexpected indent

# %%
import base64

# This is the perfectly formatted code, encoded so copy-paste can't break it
b64_code = "..."

with open("/content/xtts2-hf/app.py", "wb") as f:
    f.write(base64.b64decode(b64_code))

    print("✅ SUCCESS: The app.py file is now perfectly formatted on your server.")
# Out:
# ✅ SUCCESS: The app.py file is now perfectly formatted on your server.

# %%
# !python /content/xtts2-hf/app.py
# Out:
# Loading XTTS-v2... This takes about 60 seconds.
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a304800e5cded08981.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
# ...
